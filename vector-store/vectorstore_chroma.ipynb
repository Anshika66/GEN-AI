# %%
# %pip install langchain chromadb groq tiktoken pypdf langchain_groq langchain-community
# Out:
# Requirement already satisfied: langchain in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (0.3.30)
# Collecting chromadb
#   Downloading chromadb-1.5.9-cp39-abi3-macosx_10_12_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: groq in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (0.37.1)
# Requirement already satisfied: tiktoken in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (0.13.0)
# Requirement already satisfied: pypdf in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (6.14.2)
# Requirement already satisfied: langchain_groq in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (0.3.8)
# Requirement already satisfied: langchain-community in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (0.3.31)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.85 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain) (0.3.86)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain) (0.4.37)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain) (2.13.4)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain) (2.0.51)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain) (6.0.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.85->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.85->langchain) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.85->langchain) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.85->langchain) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.85->langchain) (0.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.85->langchain) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.17->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: anyio in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (4.12.1)
# Requirement already satisfied: certifi in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: idna in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from requests<3.0.0,>=2.0.0->langchain) (2.6.3)
# Requirement already satisfied: greenlet>=1 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain) (3.2.5)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.4.4-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pydantic-settings>=2.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from chromadb) (2.11.0)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.3-cp39-cp39-macosx_10_9_x86_64.whl.metadata (8.7 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.39.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: numpy>=1.22.5 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from chromadb) (1.26.4)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.19.2-cp39-cp39-macosx_11_0_universal2.whl.metadata (4.5 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.41.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.41.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.41.1-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from chromadb) (0.22.2)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading pypika-0.51.1-py2.py3-none-any.whl.metadata (51 kB)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from chromadb) (4.68.3)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from chromadb) (1.80.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.23.2-py3-none-any.whl.metadata (16 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-35.0.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.0-cp39-cp39-macosx_10_9_x86_64.whl.metadata (14 kB)
# Collecting rich>=10.11.0 (from chromadb)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from groq) (1.9.0)
# Requirement already satisfied: sniffio in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from groq) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: regex in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from tiktoken) (2026.1.15)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from pydantic-settings>=2.0->chromadb) (1.2.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: importlib-metadata>=4.6 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from build>=1.0.3->chromadb) (8.7.1)
# Collecting tomli>=1.1.0 (from build>=1.0.3->chromadb)
#   Using cached tomli-2.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: zipp>=3.20 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from importlib-metadata>=4.6->build>=1.0.3->chromadb) (3.23.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from jsonschema>=4.19.0->chromadb) (0.27.1)
# Requirement already satisfied: six>=1.9.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb)
#   Downloading websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: protobuf in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.6)
# Requirement already satisfied: sympy in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.41.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.41.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.41.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.41.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-semantic-conventions==0.62b1 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.62b1-py3-none-any.whl.metadata (2.5 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from tokenizers>=0.13.2->chromadb) (0.36.2)
# Requirement already satisfied: filelock in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.19.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.1)
# Requirement already satisfied: click>=8.0.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting annotated-doc>=0.0.2 (from typer>=0.9.0->chromadb)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.8.0-cp39-cp39-macosx_10_9_universal2.whl.metadata (3.5 kB)
# Collecting uvloop>=0.15.1 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvloop-0.22.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.1-cp39-cp39-macosx_10_12_x86_64.whl.metadata (4.9 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-15.0.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (6.8 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Downloading chromadb-1.5.9-cp39-abi3-macosx_10_12_x86_64.whl (22.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.6/22.6 MB 3.0 MB/s  0:00:07m0:00:0100:01
# Downloading bcrypt-5.0.0-cp39-abi3-macosx_10_12_universal2.whl (495 kB)
# Downloading build-1.4.4-py3-none-any.whl (25 kB)
# Downloading kubernetes-35.0.0-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 15.5 MB/s  0:00:00
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mmh3-5.2.0-cp39-cp39-macosx_10_9_x86_64.whl (40 kB)
# Downloading onnxruntime-1.19.2-cp39-cp39-macosx_11_0_universal2.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 34.1 MB/s  0:00:00 eta 0:00:01
# Downloading opentelemetry_api-1.41.1-py3-none-any.whl (69 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.41.1-py3-none-any.whl (20 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.41.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.41.1-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.41.1-py3-none-any.whl (180 kB)
# Downloading opentelemetry_semantic_conventions-0.62b1-py3-none-any.whl (231 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pybase64-1.4.3-cp39-cp39-macosx_10_9_x86_64.whl (38 kB)
# Downloading pypika-0.51.1-py2.py3-none-any.whl (60 kB)
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached tomli-2.4.1-py3-none-any.whl (14 kB)
# Downloading typer-0.23.2-py3-none-any.whl (56 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached uvicorn-0.39.0-py3-none-any.whl (68 kB)
# Downloading httptools-0.8.0-cp39-cp39-macosx_10_9_universal2.whl (210 kB)
# Downloading uvloop-0.22.1-cp39-cp39-macosx_10_9_x86_64.whl (743 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 743.9/743.9 kB 11.2 MB/s  0:00:00
# Downloading watchfiles-1.1.1-cp39-cp39-macosx_10_12_x86_64.whl (409 kB)
# Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Downloading websockets-15.0.1-cp39-cp39-macosx_10_9_x86_64.whl (173 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Installing collected packages: flatbuffers, durationpy, websockets, websocket-client, uvloop, uvicorn, tomli, shellingham, pyproject_hooks, pypika, pybase64, overrides, opentelemetry-proto, oauthlib, mmh3, mdurl, importlib-resources, humanfriendly, httptools, bcrypt, annotated-doc, requests-oauthlib, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, markdown-it-py, coloredlogs, build, watchfiles, rich, opentelemetry-semantic-conventions, onnxruntime, kubernetes, typer, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36/36 [chromadb]/36 [chromadb]etry-sdk]onventions]
# Successfully installed annotated-doc-0.0.4 bcrypt-5.0.0 build-1.4.4 chromadb-1.5.9 coloredlogs-15.0.1 durationpy-0.10 flatbuffers-25.12.19 httptools-0.8.0 humanfriendly-10.0 importlib-resources-6.5.2 kubernetes-35.0.0 markdown-it-py-3.0.0 mdurl-0.1.2 mmh3-5.2.0 oauthlib-3.3.1 onnxruntime-1.19.2 opentelemetry-api-1.41.1 opentelemetry-exporter-otlp-proto-common-1.41.1 opentelemetry-exporter-otlp-proto-grpc-1.41.1 opentelemetry-proto-1.41.1 opentelemetry-sdk-1.41.1 opentelemetry-semantic-conventions-0.62b1 overrides-7.7.0 pybase64-1.4.3 pypika-0.51.1 pyproject_hooks-1.2.0 requests-oauthlib-2.0.0 rich-15.0.0 shellingham-1.5.4 tomli-2.4.1 typer-0.23.2 uvicorn-0.39.0 uvloop-0.22.1 watchfiles-1.1.1 websocket-client-1.9.0 websockets-15.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install langchain-huggingface sentence-transformers
# Out:
# Requirement already satisfied: langchain-huggingface in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (0.3.1)
# Requirement already satisfied: sentence-transformers in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (5.1.2)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.70 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-huggingface) (0.3.86)
# Requirement already satisfied: tokenizers>=0.19.1 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-huggingface) (0.22.2)
# Requirement already satisfied: huggingface-hub>=0.33.4 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-huggingface) (0.36.2)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.4.37)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.13.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.25.0)
# Requirement already satisfied: anyio in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (4.12.1)
# Requirement already satisfied: certifi in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.0.9)
# Requirement already satisfied: idna in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (3.18)
# Requirement already satisfied: h11>=0.16 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (0.4.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from sentence-transformers) (4.57.6)
# Requirement already satisfied: tqdm in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from sentence-transformers) (4.68.3)
# Requirement already satisfied: torch>=1.11.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from sentence-transformers) (2.2.2)
# Requirement already satisfied: scikit-learn in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from sentence-transformers) (1.6.1)
# Requirement already satisfied: scipy in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: Pillow in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: filelock in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2026.1.15)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from huggingface-hub>=0.33.4->langchain-huggingface) (1.5.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (2.6.3)
# Requirement already satisfied: sympy in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.70->langchain-huggingface) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/apple/Desktop/Artificial Intelligence/GEN AI/.venv/lib/python3.9/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import Chroma

# %%
from langchain.schema import Document

# Create LangChain documents for IPL players

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1 , doc2 , doc3 , doc4 , doc5]

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# %%
vector_store = Chroma(
    embedding_function=embeddings,
    persist_directory='chroma_db',
    collection_name='sample'
)

# %%
vector_store.add_documents(docs)
# Out:
# ['587439ce-efb7-44f9-a5db-3f127e318fb4',
#  '2a35a8e7-fca5-4254-b64c-5cbc973913a8',
#  '88bd62ec-783a-491c-8e21-46232593cbd3',
#  '3bf1c580-ad53-4b71-bcd0-bdeec4cd49e4',
#  'e7ba835b-a0be-4cd9-8053-b5db92cacc73']

# %%
vector_store.get(include=['embeddings' , 'documents' , 'metadatas'])
# Out:
# {'ids': ['587439ce-efb7-44f9-a5db-3f127e318fb4',
#   '2a35a8e7-fca5-4254-b64c-5cbc973913a8',
#   '88bd62ec-783a-491c-8e21-46232593cbd3',
#   '3bf1c580-ad53-4b71-bcd0-bdeec4cd49e4',
#   'e7ba835b-a0be-4cd9-8053-b5db92cacc73'],
#  'embeddings': array([[ 0.00994723,  0.06914341, -0.0514711 , ..., -0.03543339,
#           0.01284806,  0.01248293],
#         [ 0.00127744,  0.03129854, -0.02375375, ..., -0.00518363,
#          -0.03280615,  0.02737714],
#         [-0.10265917,  0.02650814,  0.02271501, ..., -0.03359744,
#          -0.07984945, -0.01507708],
#         [ 0.02123396, -0.02468545, -0.04494375, ..., -0.10995816,
#           0.00572559,  0.09915377],
#         [ 0.01873982,  0.04382849, -0.04304259, ..., -0.07801618,
#          -0.07840686, -0.0030419 ]]),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
# search documents
vector_store.similarity_search(
    query='who among these are bowler?',
    k=2

    
)
# Out:
# [Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#  Document(metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.")]

# %%
# search with similarity score
vector_store.similarity_search_with_score(
    query= 'who among these are a bowler?',
    k=2
)
# Out:
# [(Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   0.9693599939346313),
#  (Document(metadata={'team': 'Mumbai Indians'}, page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure."),
#   1.1493449211120605)]

# %%
#meta data filtering 
vector_store.similarity_search_with_score(
    query="",
    filter={"team" : "Chennai Super Kings"}
)
# Out:
# [(Document(metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   1.8436007499694824),
#  (Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   1.890937328338623)]

# %%
 # update documents
updated_doc1 = Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)

vector_store.update_document(document_id='09a39dc6-3ba6-4ea7-927e-fdda591da5e4', document=updated_doc1)

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['587439ce-efb7-44f9-a5db-3f127e318fb4',
#   '2a35a8e7-fca5-4254-b64c-5cbc973913a8',
#   '88bd62ec-783a-491c-8e21-46232593cbd3',
#   '3bf1c580-ad53-4b71-bcd0-bdeec4cd49e4',
#   'e7ba835b-a0be-4cd9-8053-b5db92cacc73'],
#  'embeddings': array([[ 0.00994723,  0.06914341, -0.0514711 , ..., -0.03543339,
#           0.01284806,  0.01248293],
#         [ 0.00127744,  0.03129854, -0.02375375, ..., -0.00518363,
#          -0.03280615,  0.02737714],
#         [-0.10265917,  0.02650814,  0.02271501, ..., -0.03359744,
#          -0.07984945, -0.01507708],
#         [ 0.02123396, -0.02468545, -0.04494375, ..., -0.10995816,
#           0.00572559,  0.09915377],
#         [ 0.01873982,  0.04382849, -0.04304259, ..., -0.07801618,
#          -0.07840686, -0.0030419 ]]),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
# delete document
vector_store.delete(ids=['09a39dc6-3ba6-4ea7-927e-fdda591da5e4'])

# %%
# view documents
vector_store.get(include=['embeddings','documents', 'metadatas'])
# Out:
# {'ids': ['587439ce-efb7-44f9-a5db-3f127e318fb4',
#   '2a35a8e7-fca5-4254-b64c-5cbc973913a8',
#   '88bd62ec-783a-491c-8e21-46232593cbd3',
#   '3bf1c580-ad53-4b71-bcd0-bdeec4cd49e4',
#   'e7ba835b-a0be-4cd9-8053-b5db92cacc73'],
#  'embeddings': array([[ 0.00994723,  0.06914341, -0.0514711 , ..., -0.03543339,
#           0.01284806,  0.01248293],
#         [ 0.00127744,  0.03129854, -0.02375375, ..., -0.00518363,
#          -0.03280615,  0.02737714],
#         [-0.10265917,  0.02650814,  0.02271501, ..., -0.03359744,
#          -0.07984945, -0.01507708],
#         [ 0.02123396, -0.02468545, -0.04494375, ..., -0.10995816,
#           0.00572559,  0.09915377],
#         [ 0.01873982,  0.04382849, -0.04304259, ..., -0.07801618,
#          -0.07840686, -0.0030419 ]]),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}
